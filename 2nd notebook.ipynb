# %%
import random
from collections import Counter
import DBcm

# %%
config = {
    'host': '192.168.1.254',
    'database': 'wordgamedb',
    'user': 'worduser', 
    'password': 'wordgamepasswd'
}

# %%
allWords = []
bigWords = []
smallWords = []

with open("words.txt") as f:
    words = f.readlines()
    
    for x in words:
        allWords.append(x)
        
    for j in range(len(allWords)):
        allWords[j] = allWords[j].replace(" ", "")
        allWords[j] = allWords[j].replace("'s", "")
        allWords[j] = allWords[j].replace("\n", "")
        
    for y in allWords:
        if len(y) > 7:
            bigWords.append(y.lower())
        else:
            smallWords.append(y.lower())

# %%
smallWords
# Out:
# ['a',
#  'a',
#  'amd',
#  'amd',
#  'aol',
#  'aol',
#  'aachen',
#  'aachen',
#  'aaliyah',
#  'aaliyah',
#  'aaron',
#  'aaron',
#  'abbas',
#  'abbas',
#  'abbasid',
#  'abbasid',
#  'abbott',
#  'abbott',
#  'abby',
#  'abby',
#  'abdul',
#  'abdul',
#  'abe',
#  'abe',
#  'abel',
#  'abel',
#  'abelard',
#  'abelard',
#  'abelson',
#  'abelson',
#  'abidjan',
#  'abidjan',
#  'abigail',
#  'abigail',
#  'abilene',
#  'abilene',
#  'abner',
#  'abner',
#  'abraham',
#  'abraham',
#  'abram',
#  'abram',
#  'abrams',
#  'abrams',
#  'absalom',
#  'absalom',
#  'abuja',
#  'abuja',
#  'ac',
#  'ac',
#  'acadia',
#  'acadia',
#  'accra',
#  'accra',
#  'acevedo',
#  'acevedo',
#  'achaean',
#  'achaean',
#  'achebe',
#  'achebe',
#  'acheson',
#  'acheson',
#  'acosta',
#  'acosta',
#  'acrux',
#  'acrux',
#  'actaeon',
#  'actaeon',
#  'acton',
#  'acton',
#  'acts',
#  'acts',
#  'acuff',
#  'acuff',
#  'ada',
#  'ada',
#  'adam',
#  'adam',
#  'adams',
#  'adams',
#  'adan',
#  'adan',
#  'adana',
#  'adana',
#  'adar',
#  'adar',
#  'addams',
#  'addams',
#  'addie',
#  'addie',
#  'addison',
#  'addison',
#  'adela',
#  'adela',
#  'adele',
#  'adele',
#  'adeline',
#  'adeline',
#  'aden',
#  'aden',
#  'adhara',
#  'adhara',
#  'adidas',
#  'adidas',
#  'adkins',
#  'adkins',
#  'adler',
#  'adler',
#  'adolf',
#  'adolf',
#  'adolfo',
#  'adolfo',
#  'adolph',
#  'adolph',
#  'adonis',
#  'adonis',
#  'adrian',
#  'adrian',
#  'adriana',
#  'adriana',
#  'advent',
#  'advent',
#  'advents',
#  'advil',
#  'advil',
#  'aegean',
#  'aegean',
#  'aelfric',
#  'aelfric',
#  'aeneas',
#  'aeneas',
#  'aeneid',
#  'aeneid',
#  'aeolus',
#  'aeolus',
#  'aesop',
#  'aesop',
#  'afghan',
#  'afghan',
#  'afghani',
#  'afghani',
#  'afghans',
#  'africa',
#  'africa',
#  'african',
#  'african',
#  'afro',
#  'afro',
#  'afros',
#  'ag',
#  'ag',
#  'agassi',
#  'agassi',
#  'agassiz',
#  'agassiz',
#  'agatha',
#  'agatha',
#  'aggie',
#  'aggie',
#  'aglaia',
#  'aglaia',
#  'agnes',
#  'agnes',
#  'agnew',
#  'agnew',
#  'agni',
#  'agni',
#  'agra',
#  'agra',
#  'agrippa',
#  'agrippa',
#  'aguilar',
#  'aguilar',
#  'aguirre',
#  'aguirre',
#  'agustin',
#  'agustin',
#  'ahab',
#  'ahab',
#  'ahmad',
#  'ahmad',
#  'ahmed',
#  'ahmed',
#  'ahriman',
#  'ahriman',
#  'aida',
#  'aida',
#  'aiken',
#  'aiken',
#  'aileen',
#  'aileen',
#  'aimee',
#  'aimee',
#  'ainu',
#  'ainu',
#  'aires',
#  'aires',
#  'aisha',
#  'aisha',
#  'ajax',
#  'ajax',
#  'akbar',
#  'akbar',
#  'akihito',
#  'akihito',
#  'akita',
#  'akita',
#  'akiva',
#  'akiva',
#  'akkad',
#  'akkad',
#  'akron',
#  'akron',
#  'al',
#  'al',
#  'alabama',
#  'alabama',
#  'aladdin',
#  'aladdin',
#  'alamo',
#  'alamo',
#  'alan',
#  'alan',
#  'alana',
#  'alana',
#  'alar',
#  'alar',
#  'alaric',
#  'alaric',
#  'alaska',
#  'alaska',
#  'alaskan',
#  'alaskan',
#  'alba',
#  'alba',
#  'albania',
#  'albania',
#  'albany',
#  'albany',
#  'albee',
#  'albee',
#  'alberio',
#  'alberio',
#  'albert',
#  'albert',
#  'alberta',
#  'alberta',
#  'alberto',
#  'alberto',
#  'albion',
#  'albion',
#  'albireo',
#  'albireo',
#  'alcmena',
#  'alcmena',
#  'alcoa',
#  'alcoa',
#  'alcott',
#  'alcott',
#  'alcuin',
#  'alcuin',
#  'alcyone',
#  'alcyone',
#  'aldan',
#  'aldan',
#  'alden',
#  'alden',
#  'aldo',
#  'aldo',
#  'aldrin',
#  'aldrin',
#  'alec',
#  'alec',
#  'aleppo',
#  'aleppo',
#  'aleut',
#  'aleut',
#  'alex',
#  'alex',
#  'alexei',
#  'alexei',
#  'alexis',
#  'alexis',
#  'alfonso',
#  'alfonso',
#  'alfonzo',
#  'alfonzo',
#  'alford',
#  'alford',
#  'alfred',
#  'alfred',
#  'alfreda',
#  'alfreda',
#  'alfredo',
#  'alfredo',
#  'algenib',
#  'algenib',
#  'alger',
#  'alger',
#  'algeria',
#  'algeria',
#  'algieba',
#  'algieba',
#  'algiers',
#  'algiers',
#  'algol',
#  'algol',
#  'alhena',
#  'alhena',
#  'ali',
#  'ali',
#  'alice',
#  'alice',
#  'alicia',
#  'alicia',
#  'aline',
#  'aline',
#  'alioth',
#  'alioth',
#  'alisa',
#  'alisa',
#  'alisha',
#  'alisha',
#  'alison',
#  'alison',
#  'alissa',
#  'alissa',
#  'alkaid',
#  'alkaid',
#  'allah',
#  'allah',
#  'allan',
#  'allan',
#  'allegra',
#  'allegra',
#  'allen',
#  'allen',
#  'allende',
#  'allende',
#  'allie',
#  'allie',
#  'allison',
#  'allison',
#  'allyson',
#  'allyson',
#  'alma',
#  'alma',
#  'almach',
#  'almach',
#  'almaty',
#  'almaty',
#  'almohad',
#  'almohad',
#  'alnilam',
#  'alnilam',
#  'alnitak',
#  'alnitak',
#  'alonzo',
#  'alonzo',
#  'alpert',
#  'alpert',
#  'alphard',
#  'alphard',
#  'alpine',
#  'alpine',
#  'alpo',
#  'alpo',
#  'alps',
#  'alps',
#  'alsace',
#  'alsace',
#  'alsop',
#  'alsop',
#  'alston',
#  'alston',
#  'altai',
#  'altai',
#  'altaic',
#  'altaic',
#  'altair',
#  'altair',
#  'althea',
#  'althea',
#  'altman',
#  'altman',
#  'altoids',
#  'altoids',
#  'alton',
#  'alton',
#  'aludra',
#  'aludra',
#  'alva',
#  'alva',
#  'alvarez',
#  'alvarez',
#  'alvaro',
#  'alvaro',
#  'alvin',
#  'alvin',
#  'alyce',
#  'alyce',
#  'alyson',
#  'alyson',
#  'alyssa',
#  'alyssa',
#  'am',
#  'am',
#  'amadeus',
#  'amadeus',
#  'amado',
#  'amado',
#  'amalia',
#  'amalia',
#  'amanda',
#  'amanda',
#  'amaru',
#  'amaru',
#  'amati',
#  'amati',
#  'amazon',
#  'amazon',
#  'amazons',
#  'amber',
#  'amber',
#  'amelia',
#  'amelia',
#  'america',
#  'america',
#  'amerind',
#  'amerind',
#  'ameslan',
#  'ameslan',
#  'amharic',
#  'amharic',
#  'amherst',
#  'amherst',
#  'amie',
#  'amie',
#  'amiga',
#  'amiga',
#  'amish',
#  'amish',
#  'amman',
#  'amman',
#  'amoco',
#  'amoco',
#  'amos',
#  'amos',
#  'amparo',
#  'amparo',
#  'ampere',
#  'ampere',
#  'amtrak',
#  'amtrak',
#  'amur',
#  'amur',
#  'amway',
#  'amway',
#  'amy',
#  'amy',
#  'ana',
#  'ana',
#  'anabel',
#  'anabel',
#  'anacin',
#  'anacin',
#  'anaheim',
#  'anaheim',
#  'ananias',
#  'ananias',
#  'anasazi',
#  'anasazi',
#  'anatole',
#  'anatole',
#  'andaman',
#  'andaman',
#  'andean',
#  'andean',
#  'andes',
#  'andes',
#  'andorra',
#  'andorra',
#  'andre',
#  'andre',
#  'andrea',
#  'andrea',
#  'andrei',
#  'andrei',
#  'andres',
#  'andres',
#  'andrew',
#  'andrew',
#  'andrews',
#  'andrews',
#  'android',
#  'android',
#  'andy',
#  'andy',
#  'angara',
#  'angara',
#  'angel',
#  'angel',
#  'angela',
#  'angela',
#  'angeles',
#  'angeles',
#  'angelia',
#  'angelia',
#  'angelo',
#  'angelo',
#  'angelou',
#  'angelou',
#  'angevin',
#  'angevin',
#  'angie',
#  'angie',
#  'angkor',
#  'angkor',
#  'anglia',
#  'anglia',
#  'anglo',
#  'anglo',
#  'angola',
#  'angola',
#  'angolan',
#  'angolan',
#  'angora',
#  'angora',
#  'angoras',
#  'angus',
#  'angus',
#  'anibal',
#  'anibal',
#  'anita',
#  'anita',
#  'ankara',
#  'ankara',
#  'ann',
#  'ann',
#  'anna',
#  'anna',
#  'annabel',
#  'annabel',
#  'annam',
#  'annam',
#  'anne',
#  'anne',
#  'annette',
#  'annette',
#  'annie',
#  'annie',
#  'anouilh',
#  'anouilh',
#  'anselm',
#  'anselm',
#  'anselmo',
#  'anselmo',
#  'anshan',
#  'anshan',
#  'antaeus',
#  'antaeus',
#  'antares',
#  'antares',
#  'anthony',
#  'anthony',
#  'antigua',
#  'antigua',
#  'antioch',
#  'antioch',
#  'antipas',
#  'antipas',
#  'antoine',
#  'antoine',
#  'anton',
#  'anton',
#  'antone',
#  'antone',
#  'antonia',
#  'antonia',
#  'antonio',
#  'antonio',
#  'antony',
#  'antony',
#  'antwan',
#  'antwan',
#  'antwerp',
#  'antwerp',
#  'anubis',
#  'anubis',
#  'anzac',
#  'anzac',
#  'apache',
#  'apache',
#  'apaches',
#  'apia',
#  'apia',
#  'apollo',
#  'apollo',
#  'apollos',
#  'apple',
#  'apple',
#  'apr',
#  'apr',
#  'april',
#  'april',
#  'aprils',
#  'aquila',
#  'aquila',
#  'aquinas',
#  'aquinas',
#  'aquino',
#  'aquino',
#  'ara',
#  'ara',
#  'arab',
#  'arab',
#  'arabia',
#  'arabia',
#  'arabian',
#  'arabian',
#  'arabic',
#  'arabic',
#  'arabs',
#  'araby',
#  'araby',
#  'araceli',
#  'araceli',
#  'arafat',
#  'arafat',
#  'aral',
#  'aral',
#  'aramaic',
#  'aramaic',
#  'aramco',
#  'aramco',
#  'arapaho',
#  'arapaho',
#  'ararat',
#  'ararat',
#  'arawak',
#  'arawak',
#  'arcadia',
#  'arcadia',
#  'archean',
#  'archean',
#  'archie',
#  'archie',
#  'arctic',
#  'arctic',
#  'arden',
#  'arden',
#  'ares',
#  'ares',
#  'argo',
#  'argo',
#  'argonne',
#  'argonne',
#  'argos',
#  'argos',
#  'argus',
#  'argus',
#  'ariadne',
#  'ariadne',
#  'ariel',
#  'ariel',
#  'aries',
#  'aries',
#  'arieses',
#  'ariosto',
#  'ariosto',
#  'arius',
#  'arius',
#  'arizona',
#  'arizona',
#  'arjuna',
#  'arjuna',
#  'arlene',
#  'arlene',
#  'arline',
#  'arline',
#  'armand',
#  'armand',
#  'armando',
#  'armando',
#  'armani',
#  'armani',
#  'armenia',
#  'armenia',
#  'armonk',
#  'armonk',
#  'armour',
#  'armour',
#  'arneb',
#  'arneb',
#  'arnhem',
#  'arnhem',
#  'arno',
#  'arno',
#  'arnold',
#  'arnold',
#  'arnulfo',
#  'arnulfo',
#  'aron',
#  'aron',
#  'arron',
#  'arron',
#  'art',
#  'art',
#  'artemis',
#  'artemis',
#  'arthur',
#  'arthur',
#  'artie',
#  'artie',
#  'arturo',
#  'arturo',
#  'aruba',
#  'aruba',
#  'aryan',
#  'aryan',
#  'aryans',
#  'as',
#  'as',
#  'asama',
#  'asama',
#  'ascella',
#  'ascella',
#  'asgard',
#  'asgard',
#  'ashanti',
#  'ashanti',
#  'ashe',
#  'ashe',
#  'ashlee',
#  'ashlee',
#  'ashley',
#  'ashley',
#  'asia',
#  'asia',
#  'asiago',
#  'asian',
#  'asian',
#  'asians',
#  'asiatic',
#  'asiatic',
#  'asimov',
#  'asimov',
#  'asmara',
#  'asmara',
#  'asoka',
#  'asoka',
#  'aspell',
#  'aspell',
#  'aspen',
#  'aspen',
#  'asquith',
#  'asquith',
#  'assad',
#  'assad',
#  'assam',
#  'assam',
#  'assisi',
#  'assisi',
#  'assyria',
#  'assyria',
#  'astaire',
#  'astaire',
#  'astana',
#  'astana',
#  'astarte',
#  'astarte',
#  'aston',
#  'aston',
#  'astor',
#  'astor',
#  'astoria',
#  'astoria',
#  'aswan',
#  'aswan',
#  'atacama',
#  'atacama',
#  'atari',
#  'atari',
#  'athena',
#  'athena',
#  'athens',
#  'athens',
#  'atkins',
#  'atkins',
#  'atlanta',
#  'atlanta',
#  'atlas',
#  'atlas',
#  'atlases',
#  'atman',
#  'atman',
#  'atreus',
#  'atreus',
#  'atria',
#  'atria',
#  'atropos',
#  'atropos',
#  'ats',
#  'attic',
#  'attic',
#  'attica',
#  'attica',
#  'attila',
#  'attila',
#  'attlee',
#  'attlee',
#  'attucks',
#  'attucks',
#  'atwood',
#  'atwood',
#  'au',
#  'au',
#  'aubrey',
#  'aubrey',
#  'auden',
#  'auden',
#  'audi',
#  'audi',
#  'audion',
#  'audion',
#  'audra',
#  'audra',
#  'audrey',
#  'audrey',
#  'audubon',
#  'audubon',
#  'aug',
#  'aug',
#  'augean',
#  'augean',
#  'august',
#  'august',
#  'augusta',
#  'augusta',
#  'augusts',
#  'aurelia',
#  'aurelia',
#  'aurelio',
#  'aurelio',
#  'auriga',
#  'auriga',
#  'aurora',
#  'aurora',
#  'aussie',
#  'aussie',
#  'aussies',
#  'austen',
#  'austen',
#  'austin',
#  'austin',
#  'austins',
#  'austria',
#  'austria',
#  'autumn',
#  'autumn',
#  'ava',
#  'ava',
#  'avalon',
#  'avalon',
#  'avernus',
#  'avernus',
#  'avery',
#  'avery',
#  'avesta',
#  'avesta',
#  'avignon',
#  'avignon',
#  'avila',
#  'avila',
#  'avior',
#  'avior',
#  'avis',
#  'avis',
#  'avon',
#  'avon',
#  'axum',
#  'axum',
#  'ayala',
#  'ayala',
#  'ayers',
#  'ayers',
#  'aymara',
#  'aymara',
#  'ayyubid',
#  'ayyubid',
#  'azana',
#  'azana',
#  'azania',
#  'azania',
#  'azazel',
#  'azazel',
#  'azores',
#  'azores',
#  'azov',
#  'azov',
#  'aztec',
#  'aztec',
#  'aztecan',
#  'aztecan',
#  'aztecs',
#  'aztlan',
#  'aztlan',
#  'b',
#  'b',
#  'bbb',
#  'bbb',
#  'bmw',
#  'bmw',
#  'bp',
#  'bp',
#  'bsd',
#  'bsd',
#  'ba',
#  'ba',
#  'baal',
#  'baal',
#  'baath',
#  'baath',
#  'babar',
#  'babar',
#  'babbage',
#  'babbage',
#  'babbitt',
#  'babbitt',
#  'babel',
#  'babel',
#  'babels',
#  'babur',
#  'babur',
#  'babylon',
#  'babylon',
#  'bacall',
#  'bacall',
#  'bacardi',
#  'bacardi',
#  'bacchus',
#  'bacchus',
#  'bach',
#  'bach',
#  'backus',
#  'backus',
#  'bacon',
#  'bacon',
#  'bactria',
#  'bactria',
#  'baden',
#  'baden',
#  'baez',
#  'baez',
#  'baffin',
#  'baffin',
#  'baggies',
#  'baggies',
#  'baghdad',
#  'baghdad',
#  'baguio',
#  'baguio',
#  "baha'i",
#  "baha'i",
#  'bahama',
#  'bahama',
#  'bahamas',
#  'bahamas',
#  'bahia',
#  'bahia',
#  'bahrain',
#  'bahrain',
#  'baikal',
#  'baikal',
#  'bailey',
#  'bailey',
#  'baird',
#  'baird',
#  'baker',
#  'baker',
#  'baku',
#  'baku',
#  'bakunin',
#  'bakunin',
#  'balaton',
#  'balaton',
#  'balboa',
#  'balboa',
#  'balder',
#  'balder',
#  'baldwin',
#  'baldwin',
#  'balfour',
#  'balfour',
#  'bali',
#  'bali',
#  'balkan',
#  'balkan',
#  'balkans',
#  'balkans',
#  ...]

# %%
bigWords
# Out:
# ['aberdeen',
#  'aberdeen',
#  'abernathy',
#  'abernathy',
#  'abyssinia',
#  'abyssinia',
#  'abyssinian',
#  'abyssinian',
#  'acapulco',
#  'acapulco',
#  'accenture',
#  'accenture',
#  'achernar',
#  'achernar',
#  'achilles',
#  'achilles',
#  'aconcagua',
#  'aconcagua',
#  'acropolis',
#  'adderley',
#  'adderley',
#  'adelaide',
#  'adelaide',
#  'adenauer',
#  'adenauer',
#  'adirondack',
#  'adirondack',
#  'adirondacks',
#  'adirondacks',
#  'adonises',
#  'adriatic',
#  'adriatic',
#  'adrienne',
#  'adrienne',
#  'adventist',
#  'adventist',
#  'aeroflot',
#  'aeroflot',
#  'aeschylus',
#  'aeschylus',
#  'aesculapius',
#  'aesculapius',
#  'afghanistan',
#  'afghanistan',
#  'africans',
#  'afrikaans',
#  'afrikaans',
#  'afrikaner',
#  'afrikaner',
#  'afrikaners',
#  'afrocentrism',
#  'afrocentrism',
#  'agamemnon',
#  'agamemnon',
#  'agricola',
#  'agricola',
#  'agrippina',
#  'agrippina',
#  'aguinaldo',
#  'aguinaldo',
#  'ahmadabad',
#  'ahmadabad',
#  'ahmadinejad',
#  'ahmadinejad',
#  'airedale',
#  'airedale',
#  'airedales',
#  'akhmatova',
#  'akhmatova',
#  'alabaman',
#  'alabaman',
#  'alabamans',
#  'alabamian',
#  'alabamian',
#  'alabamians',
#  'alamogordo',
#  'alamogordo',
#  'alaskans',
#  'albanian',
#  'albanian',
#  'albanians',
#  'albigensian',
#  'albigensian',
#  'albuquerque',
#  'albuquerque',
#  'alcatraz',
#  'alcatraz',
#  'alcestis',
#  'alcestis',
#  'alcibiades',
#  'alcibiades',
#  'alcindor',
#  'alcindor',
#  'aldebaran',
#  'aldebaran',
#  'alderamin',
#  'alderamin',
#  'aleichem',
#  'aleichem',
#  'alejandra',
#  'alejandra',
#  'alejandro',
#  'alejandro',
#  'alembert',
#  'alembert',
#  'aleutian',
#  'aleutian',
#  'alexander',
#  'alexander',
#  'alexandra',
#  'alexandra',
#  'alexandria',
#  'alexandria',
#  'algerian',
#  'algerian',
#  'algerians',
#  'algonquian',
#  'algonquian',
#  'algonquians',
#  'algonquin',
#  'algonquin',
#  'alhambra',
#  'alhambra',
#  'alighieri',
#  'alighieri',
#  'alistair',
#  'alistair',
#  'allahabad',
#  'allahabad',
#  'alleghenies',
#  'alleghenies',
#  'allegheny',
#  'allegheny',
#  'allentown',
#  'allentown',
#  'allstate',
#  'allstate',
#  'almighty',
#  'almighty',
#  'almoravid',
#  'almoravid',
#  'alphecca',
#  'alphecca',
#  'alpheratz',
#  'alpheratz',
#  'alphonse',
#  'alphonse',
#  'alphonso',
#  'alphonso',
#  'alsatian',
#  'alsatian',
#  'altamira',
#  'altamira',
#  'altiplano',
#  'altiplano',
#  'alvarado',
#  'alvarado',
#  'alzheimer',
#  'alzheimer',
#  'amarillo',
#  'amarillo',
#  'amaterasu',
#  'amaterasu',
#  'amenhotep',
#  'amenhotep',
#  'amerasian',
#  'amerasian',
#  'american',
#  'american',
#  'americana',
#  'americana',
#  'americanism',
#  'americanism',
#  'americanisms',
#  'americanization',
#  'americanization',
#  'americanizations',
#  'americanize',
#  'americanized',
#  'americanizes',
#  'americanizing',
#  'americans',
#  'americas',
#  'amerindian',
#  'amerindian',
#  'amerindians',
#  'amerinds',
#  'amritsar',
#  'amritsar',
#  'amsterdam',
#  'amsterdam',
#  'amundsen',
#  'amundsen',
#  'anabaptist',
#  'anabaptist',
#  'anacreon',
#  'anacreon',
#  'analects',
#  'analects',
#  'anastasia',
#  'anastasia',
#  'anatolia',
#  'anatolia',
#  'anatolian',
#  'anatolian',
#  'anaxagoras',
#  'anaxagoras',
#  'anchorage',
#  'anchorage',
#  'andalusia',
#  'andalusia',
#  'andalusian',
#  'andalusian',
#  'andersen',
#  'andersen',
#  'anderson',
#  'anderson',
#  'andretti',
#  'andretti',
#  'andrianampoinimerina',
#  'andrianampoinimerina',
#  'andromache',
#  'andromache',
#  'andromeda',
#  'andromeda',
#  'andropov',
#  'andropov',
#  'angelica',
#  'angelica',
#  'angelico',
#  'angelico',
#  'angelina',
#  'angelina',
#  'angeline',
#  'angeline',
#  'angelique',
#  'angelique',
#  'angelita',
#  'angelita',
#  'anglican',
#  'anglican',
#  'anglicanism',
#  'anglicanism',
#  'anglicanisms',
#  'anglicans',
#  'anglicize',
#  'anglophile',
#  'anglophile',
#  'angolans',
#  'anguilla',
#  'anguilla',
#  'aniakchak',
#  'aniakchak',
#  'annabelle',
#  'annabelle',
#  'annapolis',
#  'annapolis',
#  'annapurna',
#  'annapurna',
#  'annmarie',
#  'annmarie',
#  'antananarivo',
#  'antananarivo',
#  'antarctic',
#  'antarctic',
#  'antarctica',
#  'antarctica',
#  'anthropocene',
#  'antichrist',
#  'antichrist',
#  'antichrists',
#  'antietam',
#  'antietam',
#  'antigone',
#  'antigone',
#  'antilles',
#  'antilles',
#  'antofagasta',
#  'antofagasta',
#  'antoinette',
#  'antoinette',
#  'antoninus',
#  'antoninus',
#  'antonius',
#  'antonius',
#  'apalachicola',
#  'apalachicola',
#  'apatosaurus',
#  'apennines',
#  'apennines',
#  'aphrodite',
#  'aphrodite',
#  'apocrypha',
#  'apocrypha',
#  'apollinaire',
#  'apollinaire',
#  'apollonian',
#  'apollonian',
#  'appalachia',
#  'appalachia',
#  'appalachian',
#  'appalachian',
#  'appalachians',
#  'appalachians',
#  'appaloosa',
#  'appaloosa',
#  'appleseed',
#  'appleseed',
#  'appleton',
#  'appleton',
#  'appomattox',
#  'appomattox',
#  'apuleius',
#  'apuleius',
#  'aquafresh',
#  'aquafresh',
#  'aquarius',
#  'aquarius',
#  'aquariuses',
#  'aquitaine',
#  'aquitaine',
#  'arabians',
#  'araguaya',
#  'araguaya',
#  'araucanian',
#  'araucanian',
#  'arawakan',
#  'arawakan',
#  'arbitron',
#  'arbitron',
#  'arcadian',
#  'arcadian',
#  'archibald',
#  'archibald',
#  'archimedes',
#  'archimedes',
#  'arcturus',
#  'arcturus',
#  'arequipa',
#  'arequipa',
#  'argentina',
#  'argentina',
#  'argentine',
#  'argentine',
#  'argentinian',
#  'argentinian',
#  'argentinians',
#  'argonaut',
#  'argonaut',
#  'arianism',
#  'arianism',
#  'aristarchus',
#  'aristarchus',
#  'aristides',
#  'aristides',
#  'aristophanes',
#  'aristophanes',
#  'aristotelian',
#  'aristotelian',
#  'aristotle',
#  'aristotle',
#  'arizonan',
#  'arizonan',
#  'arizonans',
#  'arizonian',
#  'arizonian',
#  'arizonians',
#  'arkansan',
#  'arkansan',
#  'arkansas',
#  'arkansas',
#  'arkhangelsk',
#  'arkhangelsk',
#  'arkwright',
#  'arkwright',
#  'arlington',
#  'arlington',
#  'armageddon',
#  'armageddon',
#  'armageddons',
#  'armagnac',
#  'armagnac',
#  'armenian',
#  'armenian',
#  'armenians',
#  'arminius',
#  'arminius',
#  'armstrong',
#  'armstrong',
#  'arrhenius',
#  'arrhenius',
#  'artaxerxes',
#  'artaxerxes',
#  'arthurian',
#  'arthurian',
#  'ashcroft',
#  'ashcroft',
#  'ashikaga',
#  'ashikaga',
#  'ashkenazim',
#  'ashkenazim',
#  'ashkhabad',
#  'ashkhabad',
#  'ashmolean',
#  'ashmolean',
#  'ashurbanipal',
#  'ashurbanipal',
#  'asiatics',
#  'asperger',
#  'asperger',
#  'aspidiske',
#  'aspidiske',
#  'assamese',
#  'assamese',
#  'assyrian',
#  'assyrian',
#  'assyrians',
#  'astrakhan',
#  'astrakhan',
#  'astroturf',
#  'astroturf',
#  'asturias',
#  'asturias',
#  'asunciãƒâ³n',
#  'asunciãƒâ³n',
#  'atahualpa',
#  'atahualpa',
#  'atalanta',
#  'atalanta',
#  'atatãƒâ¼rk',
#  'atatãƒâ¼rk',
#  'athabasca',
#  'athabasca',
#  'athabascan',
#  'athabascan',
#  'athenian',
#  'athenian',
#  'athenians',
#  'atkinson',
#  'atkinson',
#  'atlantes',
#  'atlantic',
#  'atlantic',
#  'atlantis',
#  'atlantis',
#  'auckland',
#  'auckland',
#  'augsburg',
#  'augsburg',
#  'augustan',
#  'augustan',
#  'augustine',
#  'augustine',
#  'augustus',
#  'augustus',
#  'aurangzeb',
#  'aurangzeb',
#  'aurelius',
#  'aurelius',
#  'aureomycin',
#  'aureomycin',
#  'auschwitz',
#  'auschwitz',
#  'austerlitz',
#  'austerlitz',
#  'australasia',
#  'australasia',
#  'australia',
#  'australia',
#  'australian',
#  'australian',
#  'australians',
#  'australoid',
#  'australoid',
#  'australopithecus',
#  'australopithecus',
#  'austrian',
#  'austrian',
#  'austrians',
#  'austronesian',
#  'austronesian',
#  'aventine',
#  'aventine',
#  'averroes',
#  'averroes',
#  'avicenna',
#  'avicenna',
#  'avogadro',
#  'avogadro',
#  'ayrshire',
#  'ayrshire',
#  'ayurveda',
#  'ayurveda',
#  'azerbaijan',
#  'azerbaijan',
#  'azerbaijani',
#  'azerbaijani',
#  'baathist',
#  'baathist',
#  'babylonian',
#  'babylonian',
#  'babylons',
#  'bacchanalia',
#  'bacchanalia',
#  'badlands',
#  'badlands',
#  'baedeker',
#  'baedeker',
#  "baha'ullah",
#  "baha'ullah",
#  'bahamian',
#  'bahamian',
#  'bahamians',
#  'bakelite',
#  'bakelite',
#  'bakersfield',
#  'bakersfield',
#  'balanchine',
#  'balanchine',
#  'balearic',
#  'balearic',
#  'balinese',
#  'balinese',
#  'balkhash',
#  'balkhash',
#  'balthazar',
#  'balthazar',
#  'baltimore',
#  'baltimore',
#  'baluchistan',
#  'baluchistan',
#  'bancroft',
#  'bancroft',
#  'bangalore',
#  'bangalore',
#  'bangladesh',
#  'bangladesh',
#  'bangladeshi',
#  'bangladeshi',
#  'bangladeshis',
#  'banjarmasin',
#  'banjarmasin',
#  'banneker',
#  'banneker',
#  'bannister',
#  'bannister',
#  'baptiste',
#  'baptiste',
#  'baptists',
#  'barabbas',
#  'barabbas',
#  'barbadian',
#  'barbadian',
#  'barbadians',
#  'barbados',
#  'barbados',
#  'barbarella',
#  'barbarella',
#  'barbarossa',
#  'barbarossa',
#  'barcelona',
#  'barcelona',
#  'barnabas',
#  'barnabas',
#  'barquisimeto',
#  'barquisimeto',
#  'barranquilla',
#  'barranquilla',
#  'barrymore',
#  'barrymore',
#  'bartholdi',
#  'bartholdi',
#  'bartholomew',
#  'bartholomew',
#  'bartlett',
#  'bartlett',
#  'bartãƒâ³k',
#  'bartãƒâ³k',
#  'baryshnikov',
#  'baryshnikov',
#  'basseterre',
#  'basseterre',
#  'bastille',
#  'bastille',
#  'bathsheba',
#  'bathsheba',
#  'baudelaire',
#  'baudelaire',
#  'baudouin',
#  'baudouin',
#  'bavarian',
#  'bavarian',
#  'bayesian',
#  'bayesian',
#  'bayreuth',
#  'bayreuth',
#  'baywatch',
#  'baywatch',
#  'beardmore',
#  'beardmore',
#  'beardsley',
#  'beardsley',
#  'bearnaise',
#  'bearnaise',
#  'beatlemania',
#  'beatlemania',
#  'beatrice',
#  'beatrice',
#  'beaufort',
#  'beaufort',
#  'beaujolais',
#  'beaujolais',
#  'beaumarchais',
#  'beaumarchais',
#  'beaumont',
#  'beaumont',
#  'beauregard',
#  'beauregard',
#  'beauvoir',
#  'beauvoir',
#  'becquerel',
#  'becquerel',
#  'bedouins',
#  'beefaroni',
#  'beefaroni',
#  'beelzebub',
#  'beelzebub',
#  'beerbohm',
#  'beerbohm',
#  'beethoven',
#  'beethoven',
#  'beiderbecke',
#  'beiderbecke',
#  'belgians',
#  'belgrade',
#  'belgrade',
#  'bellatrix',
#  'bellatrix',
#  'belmopan',
#  'belmopan',
#  'belshazzar',
#  'belshazzar',
#  'benacerraf',
#  'benacerraf',
#  'benchley',
#  'benchley',
#  'benedict',
#  'benedict',
#  'benedictine',
#  'benedictine',
#  'benetton',
#  'benetton',
#  'benghazi',
#  'benghazi',
#  'benjamin',
#  'benjamin',
#  'benzedrine',
#  'benzedrine',
#  'berenice',
#  'berenice',
#  'bergerac',
#  'bergerac',
#  'berkeley',
#  'berkeley',
#  'berkshire',
#  'berkshire',
#  'berkshires',
#  'berkshires',
#  'berliner',
#  'berliner',
#  'bermudas',
#  'bernadette',
#  'bernadette',
#  'bernadine',
#  'bernadine',
#  'bernanke',
#  'bernanke',
#  'bernardo',
#  'bernardo',
#  'bernbach',
#  'bernbach',
#  'bernhardt',
#  'bernhardt',
#  'bernoulli',
#  'bernoulli',
#  'bernstein',
#  'bernstein',
#  'bertelsmann',
#  'bertelsmann',
#  'bertillon',
#  'bertillon',
#  'bertrand',
#  'bertrand',
#  'berzelius',
#  'berzelius',
#  'bessemer',
#  'bessemer',
#  'betelgeuse',
#  'betelgeuse',
#  'bethesda',
#  'bethesda',
#  'bethlehem',
#  'bethlehem',
#  'beverley',
#  'beverley',
#  'bialystok',
#  'bialystok',
#  'biblical',
#  'biblical',
#  'billings',
#  'billings',
#  'birdseye',
#  'birdseye',
#  'birkenstock',
#  'birkenstock',
#  'birmingham',
#  'birmingham',
#  'biscayne',
#  'biscayne',
#  'bismarck',
#  'bismarck',
#  'bisquick',
#  'bisquick',
#  'bittorrent',
#  'bittorrent',
#  'bjerknes',
#  'bjerknes',
#  'blackbeard',
#  'blackbeard',
#  'blackburn',
#  'blackburn',
#  'blackfoot',
#  'blackfoot',
#  'blackshirt',
#  'blackshirt',
#  'blackstone',
#  'blackstone',
#  'blackwell',
#  'blackwell',
#  'blanchard',
#  'blanchard',
#  'blankenship',
#  'blankenship',
#  'blantyre',
#  'blantyre',
#  'blavatsky',
#  'blavatsky',
#  'blenheim',
#  'blenheim',
#  'blockbuster',
#  'blockbuster',
#  'bloemfontein',
#  'bloemfontein',
#  'bloomfield',
#  'bloomfield',
#  'bloomingdale',
#  'bloomingdale',
#  'bloomsbury',
#  'bloomsbury',
#  'bluebeard',
#  'bluebeard',
#  'bluetooth',
#  'bluetooth',
#  'boccaccio',
#  'boccaccio',
#  'bodhidharma',
#  'bodhidharma',
#  'bodhisattva',
#  'bodhisattva',
#  'boeotian',
#  'boeotian',
#  'boethius',
#  'boethius',
#  'bogotãƒâ¡',
#  'bogotãƒâ¡',
#  'bohemian',
#  'bohemian',
#  'bohemians',
#  'bojangles',
#  'bojangles',
#  'bolivian',
#  'bolivian',
#  'bolivians',
#  'bollywood',
#  'bollywood',
#  'bolshevik',
#  'bolshevik',
#  'bolsheviks',
#  'bolshevism',
#  'bolshevism',
#  'bolshevist',
#  'bolshevist',
#  'boltzmann',
#  'boltzmann',
#  'bonaparte',
#  'bonaparte',
#  'bonaventure',
#  'bonaventure',
#  'bonhoeffer',
#  'bonhoeffer',
#  'boniface',
#  'boniface',
#  'bonneville',
#  'bonneville',
#  'bordeaux',
#  'bordeaux',
#  'borobudur',
#  'borobudur',
#  'bosporus',
#  'bosporus',
#  'bostonian',
#  'bostonian',
#  'botswana',
#  'botswana',
#  'botticelli',
#  'botticelli',
#  'bourbaki',
#  'bourbaki',
#  'bournemouth',
#  'bournemouth',
#  'bowditch',
#  'bowditch',
#  'boãƒâ¶tes',
#  'boãƒâ¶tes',
#  'bradbury',
#  'bradbury',
#  'braddock',
#  'braddock',
#  'bradford',
#  'bradford',
#  'bradshaw',
#  'bradshaw',
#  'bradstreet',
#  'bradstreet',
#  'brahmagupta',
#  'brahmagupta',
#  'brahmanism',
#  'brahmanism',
#  'brahmanisms',
#  'brahmans',
#  'brahmaputra',
#  'brahmaputra',
#  'brahmins',
#  'brailles',
#  'brampton',
#  'brampton',
#  'brandeis',
#  'brandeis',
#  'brandenburg',
#  'brandenburg',
#  'brasilia',
#  'brasilia',
#  'bratislava',
#  'bratislava',
#  'brattain',
#  'brattain',
#  'brazilian',
#  'brazilian',
#  'brazilians',
#  'brazzaville',
#  'brazzaville',
#  'breakspear',
#  'breakspear',
#  'breckenridge',
#  'breckenridge',
#  'brewster',
#  'brewster',
#  'brezhnev',
#  'brezhnev',
#  'bridalveil',
#  'bridalveil',
#  'bridgeport',
#  'bridgeport',
#  'bridgetown',
#  'bridgetown',
#  'bridgett',
#  'bridgett',
#  'bridgette',
#  'bridgette',
#  'bridgman',
#  'bridgman',
#  'brigadoon',
#  'brigadoon',
#  'brighton',
#  'brighton',
#  'brigitte',
#  'brigitte',
#  'brinkley',
#  'brinkley',
#  'brisbane',
#  'brisbane',
#  'britannia',
#  'britannia',
#  'britannic',
#  'britannic',
#  'britannica',
#  'britannica',
#  'britisher',
#  'brittany',
#  'brittany',
#  'brittney',
#  'brittney',
#  'broadway',
#  'broadway',
#  'broadways',
#  'brobdingnag',
#  'brobdingnag',
#  'brobdingnagian',
#  'brobdingnagian',
#  'brontosaurus',
#  'brooklyn',
#  'brooklyn',
#  'brownian',
#  'brownian',
#  'brownies',
#  'browning',
#  'browning',
#  'brownshirt',
#  'brownshirt',
#  'brownsville',
#  'brownsville',
#  'bruckner',
#  'bruckner',
#  'brueghel',
#  'brueghel',
#  'brunelleschi',
#  'brunelleschi',
#  'brunhilde',
#  'brunhilde',
#  'brunswick',
#  'brunswick',
#  'brussels',
#  'brussels',
#  'brzezinski',
#  'brzezinski',
#  'buchanan',
#  'buchanan',
#  'bucharest',
#  'bucharest',
#  'buchenwald',
#  'buchenwald',
#  'buchwald',
#  'buchwald',
#  'buckingham',
#  'buckingham',
#  'budapest',
#  'budapest',
#  'buddhism',
#  'buddhism',
#  'buddhisms',
#  'buddhist',
#  'buddhist',
#  'buddhists',
#  'budweiser',
#  'budweiser',
#  'bugzilla',
#  'bugzilla',
#  'bujumbura',
#  'bujumbura',
#  'bukharin',
#  'bukharin',
#  'bulawayo',
#  'bulawayo',
#  'bulfinch',
#  'bulfinch',
#  'bulganin',
#  'bulganin',
#  'bulgaria',
#  'bulgaria',
#  'bulgarian',
#  'bulgarian',
#  'bulgarians',
#  'bullwinkle',
#  'bullwinkle',
#  'bultmann',
#  'bultmann',
#  'bundesbank',
#  'bundesbank',
#  'bundestag',
#  'bundestag',
#  'burberry',
#  'burberry',
#  'burgoyne',
#  'burgoyne',
#  'burgundian',
#  'burgundian',
#  'burgundies',
#  'burgundy',
#  'burgundy',
#  'burnside',
#  'burnside',
#  'burroughs',
#  'burroughs',
#  'bushnell',
#  'bushnell',
#  'butterfingers',
#  'butterfingers',
#  'buxtehude',
#  'buxtehude',
#  'buãƒâ±uel',
#  ...]

# %%
wordToGuess = random.choice(bigWords)

# %%
wordToGuess
# Out:
# 'gelatinous'

# %%
wordToGuess
# Out:
# 'gelatinous'

# %%
guessWord = input("Enter Words Here: ")
# Out:
# Enter Words Here: gate gates slate tine tines late noise

# %%
guess = guessWord.split(" ")

if guess in smallWords:
    if len(guess) >= 4:
        wordGood = True

# %%
guess
# Out:
# ['gate', 'gates', 'slate', 'tine', 'tines', 'late', 'noise']

# %%
guess
# Out:
# ['gate', 'gates', 'slate', 'tine', 'tines', 'late', 'noise']

# %%
def isWordInBigWord(_word):
    bigWord = Counter(wordToGuess)
    smallWord = Counter(_word)
    isCorrect = False
    _word = smallWord - bigWord
    if bool(_word) == True:
        isCorrect = False
        print(isCorrect)
    if bool(_word) == False:
        isCorrect = True
        print(isCorrect)
    return isCorrect

# %%
for i in guess:
    isCorrect = isWordInBigWord(i)
    if isCorrect == False:
        break
# Out:
# True
# True
# True
# True
# True
# True
# True

# %%
def isWordUsedMoreThanOnce(_word,guess):
    tempGuessList = guess.copy()
    wordCounter = 0
    
    for words in tempGuessList:
        if _word == words:
            wordCounter = wordCounter + 1
            tempGuessList[tempGuessList.index(_word) ].replace(_word,'0', 1)
            
        if wordCounter > 1:
            print('word is reused')
            return True
        else:
            return False

# %%
for i in guess:
    isWordReused = isWordUsedMoreThanOnce(i, guess)
    if isWordReused == True:
        break

# %%
win = False
if len(guess) == 7:
    if isCorrect == True:
        if isWordReused == False:
            win = True
            
            print(win)
# Out:
# True
