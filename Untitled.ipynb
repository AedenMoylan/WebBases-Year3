# %%
with open('words.txt') as f:
    words = f.readlines()

# %%
import random

# %%
words
# Out:
# ['A\n',
#  "A's\n",
#  'AMD\n',
#  "AMD's\n",
#  'AOL\n',
#  "AOL's\n",
#  'Aachen\n',
#  "Aachen's\n",
#  'Aaliyah\n',
#  "Aaliyah's\n",
#  'Aaron\n',
#  "Aaron's\n",
#  'Abbas\n',
#  "Abbas's\n",
#  'Abbasid\n',
#  "Abbasid's\n",
#  'Abbott\n',
#  "Abbott's\n",
#  'Abby\n',
#  "Abby's\n",
#  'Abdul\n',
#  "Abdul's\n",
#  'Abe\n',
#  "Abe's\n",
#  'Abel\n',
#  "Abel's\n",
#  'Abelard\n',
#  "Abelard's\n",
#  'Abelson\n',
#  "Abelson's\n",
#  'Aberdeen\n',
#  "Aberdeen's\n",
#  'Abernathy\n',
#  "Abernathy's\n",
#  'Abidjan\n',
#  "Abidjan's\n",
#  'Abigail\n',
#  "Abigail's\n",
#  'Abilene\n',
#  "Abilene's\n",
#  'Abner\n',
#  "Abner's\n",
#  'Abraham\n',
#  "Abraham's\n",
#  'Abram\n',
#  "Abram's\n",
#  'Abrams\n',
#  "Abrams's\n",
#  'Absalom\n',
#  "Absalom's\n",
#  'Abuja\n',
#  "Abuja's\n",
#  'Abyssinia\n',
#  "Abyssinia's\n",
#  'Abyssinian\n',
#  "Abyssinian's\n",
#  'Ac\n',
#  "Ac's\n",
#  'Acadia\n',
#  "Acadia's\n",
#  'Acapulco\n',
#  "Acapulco's\n",
#  'Accenture\n',
# ...

# %%
len(words)
# Out:
# 102305

# %%
for i in words:
    if len(i) < 8:
        print(i)
    if len(i) >= 8:
        print("removed")
# Out:
# A
#
# A's
#
# AMD
#
# AMD's
#
# AOL
#
# AOL's
#
# Aachen
#
# removed
# removed
# removed
# Aaron
#
# removed
# Abbas
#
# removed
# removed
# removed
# Abbott
#
# removed
# Abby
#
# Abby's
#
# Abdul
#
# removed
# Abe
#
# Abe's
#
# Abel
#
# Abel's
#
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# Abner
#
# removed
# removed
# removed
# Abram
#
# removed
# Abrams
#
# removed
# removed
# removed
# Abuja
#
# removed
# removed
# removed
# removed
# removed
# Ac
#
# Ac's
#
# Acadia
#
# removed
# removed
# removed
# removed
# removed
# Accra
#
# removed
# removed
# removed
# removed
# removed
# Achebe
#
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# Acosta
#
# removed
# removed
# Acrux
#
# removed
# removed
# removed
# Acton
#
# removed
# Acts
#
# Acts's
#
# Acuff
#
# removed
# Ada
#
# Ada's
#
# Adam
#
# Adam's
#
# Adams
#
# removed
# Adan
#
# Adan's
#
# ...

# %%
for i in words:
    if len(i) < 8:
        print(i)
    else if len(i) >= 8:
        print("removed")
# Out:
#   File "C:\Users\C00249~1\AppData\Local\Temp/ipykernel_30448/3977872452.py", line 4
#     else if len(i) >= 8:
#          ^
# SyntaxError: invalid syntax

# %%
for smallWords in words:
    if len(smallWords) < 8:
        smallWords.pop(smallWords)

# %%
smallWords

# %%
bigwords

# %%
for i in words:
type(i)

# %%
for i in words:
i

# %%
for i in words:
print(type(i))

# %%
for i in words:
    if len(i) < 8:
        smallWords.append(i)
    if len(i) >= 8:
        print("removed")

# %%
for i in words:
    if len(i) < 8:
        smallWords.append(i)
    if len(i) >= 8:
        print("removed")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\C00249~1\AppData\Local\Temp/ipykernel_1636/2314585950.py in <module>
#       1 for i in words:
#       2     if len(i) < 8:
# ----> 3         smallWords.append(i)
#       4     if len(i) >= 8:
#       5         print("removed")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
smallWords = []
bigWords = []

for i in words:
    if len(i) < 8:
        smallWords.append(i)
    if len(i) >= 8:
        bigWords.append(i)

# %%
smallwords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\C00249~1\AppData\Local\Temp/ipykernel_1636/2325575392.py in <module>
# ----> 1 smallwords
#
# NameError: name 'smallwords' is not defined

# %%
smallWords
# Out:
# ['A\n',
#  "A's\n",
#  'AMD\n',
#  "AMD's\n",
#  'AOL\n',
#  "AOL's\n",
#  'Aachen\n',
#  'Aaron\n',
#  'Abbas\n',
#  'Abbott\n',
#  'Abby\n',
#  "Abby's\n",
#  'Abdul\n',
#  'Abe\n',
#  "Abe's\n",
#  'Abel\n',
#  "Abel's\n",
#  'Abner\n',
#  'Abram\n',
#  'Abrams\n',
#  'Abuja\n',
#  'Ac\n',
#  "Ac's\n",
#  'Acadia\n',
#  'Accra\n',
#  'Achebe\n',
#  'Acosta\n',
#  'Acrux\n',
#  'Acton\n',
#  'Acts\n',
#  "Acts's\n",
#  'Acuff\n',
#  'Ada\n',
#  "Ada's\n",
#  'Adam\n',
#  "Adam's\n",
#  'Adams\n',
#  'Adan\n',
#  "Adan's\n",
#  'Adana\n',
#  'Adar\n',
#  "Adar's\n",
#  'Addams\n',
#  'Addie\n',
#  'Adela\n',
#  'Adele\n',
#  'Aden\n',
#  "Aden's\n",
#  'Adhara\n',
#  'Adidas\n',
#  'Adkins\n',
#  'Adler\n',
#  'Adolf\n',
#  'Adolfo\n',
#  'Adolph\n',
#  'Adonis\n',
#  'Adrian\n',
#  'Advent\n',
#  'Advil\n',
#  'Aegean\n',
#  'Aeneas\n',
#  'Aeneid\n',
#  'Aeolus\n',
#  'Aesop\n',
#  'Afghan\n',
#  'Africa\n',
#  'Afro\n',
#  "Afro's\n",
#  'Afros\n',
#  'Ag\n',
#  "Ag's\n",
# ...

# %%
bigWords
# Out:
# ["Aachen's\n",
#  'Aaliyah\n',
#  "Aaliyah's\n",
#  "Aaron's\n",
#  "Abbas's\n",
#  'Abbasid\n',
#  "Abbasid's\n",
#  "Abbott's\n",
#  "Abdul's\n",
#  'Abelard\n',
#  "Abelard's\n",
#  'Abelson\n',
#  "Abelson's\n",
#  'Aberdeen\n',
#  "Aberdeen's\n",
#  'Abernathy\n',
#  "Abernathy's\n",
#  'Abidjan\n',
#  "Abidjan's\n",
#  'Abigail\n',
#  "Abigail's\n",
#  'Abilene\n',
#  "Abilene's\n",
#  "Abner's\n",
#  'Abraham\n',
#  "Abraham's\n",
#  "Abram's\n",
#  "Abrams's\n",
#  'Absalom\n',
#  "Absalom's\n",
#  "Abuja's\n",
#  'Abyssinia\n',
#  "Abyssinia's\n",
#  'Abyssinian\n',
#  "Abyssinian's\n",
#  "Acadia's\n",
#  'Acapulco\n',
#  "Acapulco's\n",
#  'Accenture\n',
#  "Accenture's\n",
#  "Accra's\n",
#  'Acevedo\n',
#  "Acevedo's\n",
#  'Achaean\n',
#  "Achaean's\n",
#  "Achebe's\n",
#  'Achernar\n',
#  "Achernar's\n",
#  'Acheson\n',
#  "Acheson's\n",
#  'Achilles\n',
#  "Achilles's\n",
#  'Aconcagua\n',
#  "Aconcagua's\n",
#  "Acosta's\n",
#  'Acropolis\n',
#  "Acrux's\n",
# ...

# %% [raw]
# lower(words)

# %%
words
# Out:
# ['A\n',
#  "A's\n",
#  'AMD\n',
#  "AMD's\n",
#  'AOL\n',
#  "AOL's\n",
#  'Aachen\n',
#  "Aachen's\n",
#  'Aaliyah\n',
#  "Aaliyah's\n",
#  'Aaron\n',
#  "Aaron's\n",
#  'Abbas\n',
#  "Abbas's\n",
#  'Abbasid\n',
#  "Abbasid's\n",
#  'Abbott\n',
#  "Abbott's\n",
#  'Abby\n',
#  "Abby's\n",
#  'Abdul\n',
#  "Abdul's\n",
#  'Abe\n',
#  "Abe's\n",
#  'Abel\n',
#  "Abel's\n",
#  'Abelard\n',
#  "Abelard's\n",
#  'Abelson\n',
#  "Abelson's\n",
#  'Aberdeen\n',
#  "Aberdeen's\n",
#  'Abernathy\n',
#  "Abernathy's\n",
#  'Abidjan\n',
#  "Abidjan's\n",
#  'Abigail\n',
#  "Abigail's\n",
#  'Abilene\n',
#  "Abilene's\n",
#  'Abner\n',
#  "Abner's\n",
#  'Abraham\n',
#  "Abraham's\n",
#  'Abram\n',
#  "Abram's\n",
#  'Abrams\n',
#  "Abrams's\n",
#  'Absalom\n',
#  "Absalom's\n",
#  'Abuja\n',
#  "Abuja's\n",
#  'Abyssinia\n',
#  "Abyssinia's\n",
#  'Abyssinian\n',
#  "Abyssinian's\n",
#  'Ac\n',
#  "Ac's\n",
#  'Acadia\n',
#  "Acadia's\n",
#  'Acapulco\n',
#  "Acapulco's\n",
#  'Accenture\n',
# ...

# %%
words.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\C00249~1\AppData\Local\Temp/ipykernel_1636/1589880076.py in <module>
# ----> 1 words.lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
for i in words:
    if len(i) < 8:
        smallWords.append(i)
    if len(i) >= 8:
        print("removed")
# Out:
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# removed
# ...

# %%
smallwords.lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\C00249~1\AppData\Local\Temp/ipykernel_1636/2173144506.py in <module>
# ----> 1 smallwords.lower()
#
# NameError: name 'smallwords' is not defined

# %%
smallWords = []
bigWords = []

for i in words:
    if len(i) < 8:
        smallWords.append(i)
    if len(i) >= 8:
        bigWords.append(i)
        
        smallWords.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\C00249~1\AppData\Local\Temp/ipykernel_1636/4166102668.py in <module>
#       8         bigWords.append(i)
#       9
# ---> 10         smallWords.lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
smallWords = []
bigWords = []

for i in words:
    if len(i) < 8:
        smallWords.append(i)
    if len(i) >= 8:
        bigWords.append(i)
        
        lower(smalWords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\C00249~1\AppData\Local\Temp/ipykernel_1636/3152045830.py in <module>
#       8         bigWords.append(i)
#       9
# ---> 10         lower(smalWords)
#
# NameError: name 'lower' is not defined

# %%
smallWords = []
bigWords = []

for i in words:
    if len(i) < 8:
        smallWords.append(i)
    if len(i) >= 8:
        bigWords.append(i)
        
        lower(smalWords)

smallWords = smallWords.lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\C00249~1\AppData\Local\Temp/ipykernel_1636/602669822.py in <module>
#       8         bigWords.append(i)
#       9
# ---> 10         lower(smalWords)
#      11
#      12 smallWords = smallWords.lower()
#
# NameError: name 'lower' is not defined

# %%
smallWords = []
bigWords = []

for i in words:
    if len(i) < 8:
        smallWords.append(i)
    if len(i) >= 8:
        bigWords.append(i)
        
        lower(smalWords)
        
for i in range(len(smallWords)):

    smallWords[i] = smallWords[i].lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\C00249~1\AppData\Local\Temp/ipykernel_1636/332470765.py in <module>
#       8         bigWords.append(i)
#       9
# ---> 10         lower(smalWords)
#      11
#      12 for i in range(len(smallWords)):
#
# NameError: name 'lower' is not defined

# %%
smallWords = []
bigWords = []

for i in words:
    if len(i) < 8:
        smallWords.append(i)
    if len(i) >= 8:
        bigWords.append(i)
        
for i in range(len(smallWords)):

    smallWords[i] = smallWords[i].lower()
    
for i in range(len(bigWords)):

    bigWords[i] = bigWords[i].lower()

# %%
smallWords
